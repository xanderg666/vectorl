# %%
import os
import sys
from grok_assistant import GrokOCIAssistant

# %%
grok = GrokOCIAssistant()

# %%
response = grok.generate_response(
            prompt="Hola, ¿cómo estás? Preséntate brevemente.",
            model_name="grok-4"
        )

# %%
response

# %%
assistant = GrokOCIAssistant()

# Puedes mezclar imágenes, PDFs y texto
response = assistant.generate_response(
    prompt="Analiza estos documentos y dime qué ves en la imagen",
    files=[
        "documento.pdf",      # Se procesa visualmente
        "foto.jpg",           # Se procesa visualmente
        "datos.json",         # Se lee como texto
        "notas.txt"           # Se lee como texto
    ]
)
